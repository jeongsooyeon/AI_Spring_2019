# %% [markdown]
# ### Perceptrons - Making Predictions

# %% [markdown]
# Assuming that we have
# ```
# weights = [-0.1, 0.206, -0.234]
# ```

# %%
def predict2(X, w):
    activation = w[0] + w[1]* X[0] + w[2]* X[1] #w는 0,1,2 : 3개,,  x는 0,1 : 1개 #w[0]는 bias, x값은 외부에서 옴
    if activation >= 0.0:
        return 1.0
    else:
        return 0.0

# %%
# test predictions
dataset = [[2.7810836,2.550537003,0], 
    [1.465489372,2.362125076,0],
    [3.396561688,4.400293529,0],
    [1.38807019,1.850220317,0],
    [3.06407232,3.005305973,0],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]]

# %%
bias = -0.1
w0 = 0.206
w1 = 0.204
weights = [-0.1, 0.206, -0.234] #weights를 강제로 넣었다
print(weights)
# Out:
# [-0.1, 0.206, -0.234]

# %%
for row in dataset:
  #print(row) #data를 한 줄씩 가져오자
  print(row[0], row[1], row[2], row[-1])
# Out:
# 2.7810836 2.550537003 0 0
# 1.465489372 2.362125076 0 0
# 3.396561688 4.400293529 0 0
# 1.38807019 1.850220317 0 0
# 3.06407232 3.005305973 0 0
# 7.627531214 2.759262235 1 1
# 5.332441248 2.088626775 1 1
# 6.922596716 1.77106367 1 1
# 8.675418651 -0.242068655 1 1
# 7.673756466 3.508563011 1 1

# %%
for row in dataset:
    prediction = predict2(row, weights)
    answer = row[-1]
    print("Expected={}, Predicted={}".format(row[-1], prediction))
# Out:
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0

# %% [markdown]
# * More fancy !

# %%
def predict(row, weights):
    activation = weights[0]
    for i in range(len(row)-1):
        activation += weights[i + 1] * row[i]
    return 1.0 if activation >= 0.0 else 0.0

# %%
for row in dataset:
    prediction = predict(row, weights)
    print("Expected={}, Predicted={}".format(row[-1], prediction))
# Out:
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=0, Predicted=0.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0
# Expected=1, Predicted=1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(3,4,'r.') #점을 찍는 모양을'.'로 #빨간점은 '.'앞에 'r'
plt.plot(2,3,'b.')
plt.plot(2.5,3,'o')
plt.plot(2,3.5,'^')
plt.plot(2,4,'*')

# %%
for row in dataset:
  pred = predict2(row, weights)
  answer = row[-1]
  if pred == 0:
    plt.plot(row[0], row[1], 'b.')
  else:
    plt.plot(row[0], row[1], 'r^')

# %%
pred= predict2([5,4], weights)
print(pred)
# Out:
# 0.0

# %%
#퍼센트론은 공간을 나누는 역할을 한다.
for j in range(50):
  for i in range(99):
    x = i * 0.1 #곱하는 수 작게 할 수록 빼곡하게 찍힘
    y = j *0.1
    pred = predict2([x, y], weights)

    if pred == 0:
      plt.plot(x, y, 'b.')
    else:
      plt.plot(x, y, 'r.')

# %% [markdown]
# #### References

# %% [markdown]
# https://machinelearningmastery.com/implement-perceptron-algorithm-scratch-python/

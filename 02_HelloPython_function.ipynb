# %% [markdown]
# # Python tutorial #2

# %% [markdown]
# Function & Class 를 학습합니다.

# %%
def hello():
    print("Hello World")

# %%
hello()
# Out:
# Hello World

# %%
def hello(object):
    print("Hello " + object + "!")

# %%
hello("cat")
# Out:
# Hello cat!

# %%
def mySum(a, b): # a와 b를 받아서 return
    return a+ 2*b # a+b 였을때는 print(c) ---> 5 였었다.

# %%
c = mySum(2, 3)
print(c)
# Out:
# 8

# %%
class Man:
    def __init__(self, name):
        self.name = name
        print("Initialized!")
        
    def hello(self):
        print("Hello " + self.name + " !")
        
    def goodbye(self):
        print("Good-bye " + self.name + " !")

# %%
m = Man("David")
# Out:
# Initialized!

# %%
m.hello()
# Out:
# Hello David !

# %%
m.goodbye()
# Out:
# Good-bye David !
